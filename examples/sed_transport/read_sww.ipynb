# %%
from matplotlib import pyplot as plt
# %matplotlib inline
from anuga.utilities import plot_utils as util
import numpy as np


swwFile = 'new_domain_test2.sww'

filename = swwFile
timeslice = 0

p=util.get_output(swwFile)

d = p.elev[-1]

plt.scatter(p.x, p.y, c = p.stage[timeslice], edgecolors='none')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x131d081b8>

# %%
p=util.get_output(swwFile)

plt.scatter(p.x, p.y, c = p.elev[-1], edgecolors='none', alpha = 0.75)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x131fed518>

# %%
plt.scatter(p.x, p.y, c = p.elev[-1] - p.elev[0], edgecolors='none')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x133840170>

# %%
inds = np.intersect1d(np.where(p.x == 3.0)[0], np.where(p.y == 1.)[0])

p.elev[-1][inds]

# p.y[np.where(p.x == 4.0)[0]]
# Out:
# array([ 9.93840599,  9.93856621,  9.93854523,  9.93804646,  9.93777275,
#         9.93630886,  9.93733597,  9.936059  ], dtype=float32)

# %%
from anuga.file.netcdf import NetCDFFile

# Open ncdf connection
fid=NetCDFFile(swwFile)

# Get concentration
if(fid.variables.has_key('concentration')):
    conc = fid.variables['concentration'][:]


fid.close()

# %%
plt.scatter(p.x, p.y, c = conc[5], edgecolors = 'none')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1334d4fc8>
