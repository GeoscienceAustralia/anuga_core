# %%
from matplotlib import pyplot as plt
# %matplotlib inline
from anuga.utilities import plot_utils as util
import numpy as np


swwFile = 'output_run_bed_shear_erosion.sww'
timeslice = 0

p=util.get_output(swwFile)

plt.scatter(p.x, p.y, c = p.elev[timeslice], edgecolors='none')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11bfdd878>

# %%
p=util.get_output(swwFile)

plt.scatter(p.x, p.y, c = p.elev[-1], edgecolors='none')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11bc57098>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-7075f374f446> in <module>()
# ----> 1 rectangular_cross()
#
# TypeError: rectangular_cross() takes at least 2 arguments (0 given)
