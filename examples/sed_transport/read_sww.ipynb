# %%
from matplotlib import pyplot as plt
# %matplotlib inline
from anuga.utilities import plot_utils as util
import numpy as np
from anuga.file import netcdf


swwFile = 'new_domain_test2.sww'
timeslice = 0

fid = netcdf.NetCDFFile(swwFile)

x = fid.variables['x'][:]
y = fid.variables['y'][:]
elev = fid.variables['elevation'][:]
stage = fid.variables['stage'][:]

try:
    conc = fid.variables['concentration'][:]
except:
    pass


fid.close()


plt.scatter(x, y, c = elev[timeslice], edgecolors='none')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x112092cf8>

# %%
plt.scatter(x, y, c = elev[-1], edgecolors='none', alpha = 0.75)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1123a3b90>

# %%
plt.scatter(x, y, c = elev[-1] - elev[0], edgecolors='none', alpha = 0.25)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11435e8c0>

# %%
inds = np.intersect1d(np.where(x == 3.0)[0], np.where(y == 1.)[0])

elev[-1][inds] - elev[0][inds]
# Out:
# array([-0.00102711], dtype=float32)

# %%
inds = np.intersect1d(np.where(x == 5.0)[0], np.where(y == 1.)[0])

elev[-1][inds] - elev[0][inds]

# p.y[np.where(p.x == 4.0)[0]]
# Out:
# array([-0.00118256], dtype=float32)

# %%
plt.scatter(x, y, c = conc[-5], edgecolors = 'none')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11337f1b8>

# %%
inds = np.intersect1d(np.where(x == 3.0)[0], np.where(y == 1.)[0])

stage[-1][inds] - elev[-1][inds]
# Out:
# array([ 0.4466095], dtype=float32)

# %%
inds = np.intersect1d(np.where(x == 3.2)[0], np.where(y == 1.)[0])
np.sort(conc[-1][inds])
# Out:
# array([ 0.00510593], dtype=float32)

# %%
inds = np.intersect1d(np.where(x == 3.1)[0], np.where(y == 0.9)[0])
np.sort(conc[-1][inds])
# Out:
# array([ 0.005103], dtype=float32)

# %%
max(elev[-1] - elev[0])
# Out:
# 0.034597397

# %%
elev[0]
# Out:
# array([ 20.        ,  17.49966621,  10.83199978,   9.99866676,
#          9.99866676,   9.99866676,   9.99866676,   9.99866676,
#          9.99866676,   9.99866676,   9.99866676,   9.99866676,
#          9.99866676,  10.83199978,  17.49966621,  20.        ,
#         20.        ,  17.49900055,  10.82966709,   9.99600029,
#          9.99600029,   9.99600029,   9.99600029,   9.99600029,
#          9.99600029,   9.99600029,   9.99600029,   9.99600029,
#          9.99600029,  10.82966709,  17.49900055,  20.        ,
#         20.        ,  17.49799919,  10.82600021,   9.99199963,
#          9.99199963,   9.99199963,   9.99199963,   9.99199963,
#          9.99199963,   9.99199963,   9.99199963,   9.99199963,
#          9.99199963,  10.82600021,  17.49799919,  20.        ,
#         20.        ,  17.49699974,  10.82233334,   9.98799992,
#          9.98799992,   9.98799992,   9.98799992,   9.98799992,
#          9.98799992,   9.98799992,   9.98799992,   9.98799992,
# ...
